# %% [markdown]
# The main idea of this notebook is that you can try to move families to different days, or switch them with other families, and evaluate the decision bases on calculating only the elements of the cost function that would change due to the move, rather than calculating the entire cost each time.

# %% [markdown]
# Import libraries

# %%
import numpy as np 
import pandas as pd 
import time
import os

# %% [markdown]
# Read in data and initialize some variables that will be useful later on.  Most of this code was borrowed from the starter notebook.

# %%
df = pd.read_csv('/kaggle/input/santa-workshop-tour-2019/family_data.csv', index_col = 'family_id')
submission = pd.read_csv('/kaggle/input/santa-workshop-tour-2019/sample_submission.csv', index_col = 'family_id')

# %%
family_size_dict = df[['n_people']].to_dict()['n_people']

cols = [f'choice_{i}' for i in range(10)]
choice_dict = df[cols].to_dict()

# %%
N_DAYS = 100
MAX_OCCUPANCY = 300
MIN_OCCUPANCY = 125

days = list(range(N_DAYS, 0, -1))

# %% [markdown]
# Define a function that will calculate the total cost, given a prediction.  Again, this is borrowed from the starter notebook.

# %%
def cost_function(prediction):
    
    penalty = 0
    daily_occupancy_cost = {k: 0 for k in days}
    
    for f, d in enumerate(prediction):
        
        n = family_size_dict[f]
        choice_0 = choice_dict['choice_0'][f]
        choice_1 = choice_dict['choice_1'][f]
        choice_2 = choice_dict['choice_2'][f]
        choice_3 = choice_dict['choice_3'][f]
        choice_4 = choice_dict['choice_4'][f]
        choice_5 = choice_dict['choice_5'][f]
        choice_6 = choice_dict['choice_6'][f]
        choice_7 = choice_dict['choice_7'][f]
        choice_8 = choice_dict['choice_8'][f]
        choice_9 = choice_dict['choice_9'][f]
        
        daily_occupancy_cost[d] += n
        
        if d == choice_0:
            penalty += 0
        elif d == choice_1:
            penalty += 50
        elif d == choice_2:
            penalty += 50 + 9 * n
        elif d == choice_3:
            penalty += 100 + 9 * n
        elif d == choice_4:
            penalty += 200 + 9 * n
        elif d == choice_5:
            penalty += 200 + 18 * n
        elif d == choice_6:
            penalty += 300 + 18 * n
        elif d == choice_7:
            penalty += 300 + 36 * n
        elif d == choice_8:
            penalty += 400 + 36 * n
        elif d == choice_9:
            penalty += 500 + 36 * n + 199 * n
        else:
            penalty += 500 + 36 * n + 398 * n
            
    for _, v in daily_occupancy_cost.items():
        if (v > MAX_OCCUPANCY) or (v < MIN_OCCUPANCY):
            penalty += 100000000

    accounting_cost = (daily_occupancy_cost[days[0]] - 125.0) / 400.0 * daily_occupancy_cost[days[0]]**(0.5)
    accounting_cost = max(0, accounting_cost)

    yesterday_count = daily_occupancy_cost[days[0]]

    for day in days[1:]:
        today_count = daily_occupancy_cost[day]
        diff = abs(today_count - yesterday_count)
        accounting_cost += max(0, (daily_occupancy_cost[day] - 125.0) / 400.0 * daily_occupancy_cost[day]**(0.5 + diff / 50.0))
        yesterday_count = today_count
    penalty += accounting_cost

    return penalty

# %% [markdown]
# Define a function that calculates the penalty for a family based on the day that they're assigned to.  We'll also use this function to run through the daily occupancy and add a heavy penalty if the number of people on any day isn't between 125 and 300, as required.

# %%
def calc_family_penalty(f, d, daily_occupancy_fn):
    penalty = 0
    
    n = family_size_dict[f]
    choice_0 = choice_dict['choice_0'][f]
    choice_1 = choice_dict['choice_1'][f]
    choice_2 = choice_dict['choice_2'][f]
    choice_3 = choice_dict['choice_3'][f]
    choice_4 = choice_dict['choice_4'][f]
    choice_5 = choice_dict['choice_5'][f]
    choice_6 = choice_dict['choice_6'][f]
    choice_7 = choice_dict['choice_7'][f]
    choice_8 = choice_dict['choice_8'][f]
    choice_9 = choice_dict['choice_9'][f]

    if d == choice_0:
        penalty += 0
    elif d == choice_1:
        penalty += 50
    elif d == choice_2:
        penalty += 50 + 9 * n
    elif d == choice_3:
        penalty += 100 + 9 * n
    elif d == choice_4:
        penalty += 200 + 9 * n
    elif d == choice_5:
        penalty += 200 + 18 * n
    elif d == choice_6:
        penalty += 300 + 18 * n
    elif d == choice_7:
        penalty += 300 + 36 * n
    elif d == choice_8:
        penalty += 400 + 36 * n
    elif d == choice_9:
        penalty += 500 + 36 * n + 199 * n
    else:
        penalty += 500 + 36 * n + 398 * n
            
    for _, v in daily_occupancy_fn.items():
        if (v > MAX_OCCUPANCY) or (v < MIN_OCCUPANCY):
            penalty += 100000000
            
    return penalty

# %% [markdown]
# Define a function that calculates the accounting penalty for a specific day.

# %%
def accounting_day(day, daily_occupancy_2):
    if(day != 100):
        diff = abs(daily_occupancy_2[day + 1] - daily_occupancy_2[day])
        return max(0, (daily_occupancy_2[day] - 125.0) / 400.0 * daily_occupancy_2[day]**(0.5 + diff / 50.0))
    else:
        return (daily_occupancy_2[day] - 125.0) / 400.0 * daily_occupancy_2[day]**(0.5)

# %% [markdown]
# This is starter code again.  We start by using the 'cost_function' and try to move each family to a day on their list.

# %%
best = submission['assigned_day'].tolist()
start_score = cost_function(best)
print(start_score)
new = best.copy()
'''
for fam_id, _ in enumerate(best):
    for pick in range(10):
        day = choice_dict[f'choice_{pick}'][fam_id]
        temp = new.copy()
        temp[fam_id] = day
        new_cost = cost_function(temp)
        if(new_cost < start_score):
            new = temp.copy()
            start_score = new_cost
'''
# Out:
# 10641498.403135022
# "\nfor fam_id, _ in enumerate(best):\n    for pick in range(10):\n        day = choice_dict[f'choice_{pick}'][fam_id]\n        temp = new.copy()\n        temp[fam_id] = day\n        new_cost = cost_function(temp)\n        if(new_cost < start_score):\n            new = temp.copy()\n            start_score = new_cost\n"

# %% [markdown]
# Initialize a global variable to track the daily occupancy for each day, which we can pass to the accounting_day and calc_family_penalty functions.

# %%
daily_occupancy = {k: 0 for k in days}

for f, d in enumerate(new):   
        n = family_size_dict[f]
        daily_occupancy[d] += n

# %% [markdown]
# A method that tries to move every family to every other day, and keeps them there if the cost decreases.  Note that the total cost isn't calculated each time (it would take too long).  Instead, only the parts of the total cost that *change* are calculated, before and after the move.

# %%
def change_family_days():
    
    global daily_occupancy
    
    for fam_id in range(5000):
            
            # try moving them to every day
            for i in range(1, 101):
                
                fam1_day = new[fam_id]
                
                # accounting cost for the family's current day, before switching them
                accounting_current_before_1 = accounting_day(fam1_day, daily_occupancy)
                
                # accounting cost for the day before the family's current day, before switching them
                if((fam1_day != 1) & (i != fam1_day - 1)):
                    accounting_current_before_2 = accounting_day(fam1_day - 1, daily_occupancy)
                else: 
                    accounting_current_before_2 = 0
                    
                # accounting cost for the day we're going to try to move the family to, before switching them
                accounting_future_before_1 = accounting_day(i, daily_occupancy)
                
                # accounting cost for the day before the day we're going to try to move the family to, before switching them
                if((i != 1) & (fam1_day != i - 1)):
                    accounting_future_before_2 = accounting_day(i - 1, daily_occupancy)
                else: 
                    accounting_future_before_2 = 0
                    
                # the penalty based on the family's choices, before moving them
                fam1_penalty_before = calc_family_penalty(fam_id, fam1_day, daily_occupancy)
                
                # the total cost of the things that will change after we move the family
                before = accounting_current_before_1 + accounting_current_before_2 + fam1_penalty_before + accounting_future_before_1 + accounting_future_before_2

                # move the family by updating the daily occupancy
                daily_occupancy_temp = daily_occupancy.copy()
                daily_occupancy_temp[fam1_day] = daily_occupancy_temp[fam1_day] - family_size_dict[fam_id]
                daily_occupancy_temp[i] = daily_occupancy_temp[i] + family_size_dict[fam_id]

                # accounting cost for the day the family is moving to, after we've moved them
                accounting_future_after_1 = accounting_day(i, daily_occupancy_temp)
                
                # accounting cost for the day before the one the family is moving to, after we've moved them
                if((i != 1) & (fam1_day != i - 1)):
                    accounting_future_after_2 = accounting_day(i - 1, daily_occupancy_temp)
                else: 
                    accounting_future_after_2 = 0
                
                # accounting cost for the day the family started on, after we've moved them
                accounting_day_current_after_1 = accounting_day(fam1_day, daily_occupancy_temp)
                
                # accounting cost for the day before the one the family started on, after we've moved them
                if((fam1_day != 1) & (i != fam1_day - 1)):
                    accounting_current_after_2 = accounting_day(fam1_day - 1, daily_occupancy_temp)
                else: 
                    accounting_current_after_2 = 0
                
                # the penalty based on the family's choices, after moving them
                fam1_penalty_post = calc_family_penalty(fam_id, i, daily_occupancy_temp)
                
                # the total cost of the things that will change after we've moved the family
                after = accounting_future_after_1 + accounting_future_after_2 + fam1_penalty_post + accounting_day_current_after_1 + accounting_current_after_2

                # if the overall cost has decreased, move them
                if(before > after):
                    print(f'Switching {fam_id} from day {fam1_day} to day {i}')
                    new[fam_id] = i 
                    daily_occupancy = daily_occupancy_temp.copy()

# %% [markdown]
# A method that tries to switch each family with each other family, and keeps them there if the cost decreases.  Note that the total cost isn't calculated each time (it would take too long).  Instead, only the parts of the total cost that *change* are calculated, before and after the move.

# %%
def swap_families():
    
    global daily_occupancy
    
    for fam_id in range(5000):
        for fam_id2 in range(5000):
            if fam_id2 == fam_id:
                continue
  
            fam1_day = new[fam_id]
            fam2_day = new[fam_id2]
            
            accounting_fam1_before_1 = accounting_day(fam1_day, daily_occupancy)
            
            if((fam1_day != 1) & (fam1_day - 1 != fam2_day)):
                accounting_fam1_before_2 = accounting_day(fam1_day - 1, daily_occupancy)
            else: 
                accounting_fam1_before_2 = 0
                
            accounting_fam2_before_1 = accounting_day(fam2_day, daily_occupancy)
            
            if((fam2_day != 1) & (fam2_day - 1 != fam1_day)):
                accounting_fam2_before_2 = accounting_day(fam2_day - 1, daily_occupancy)
            else:
                accounting_fam2_before_2 = 0
                
            fam1_penalty_pre = calc_family_penalty(fam_id, fam1_day, daily_occupancy)
            fam2_penalty_pre = calc_family_penalty(fam_id2, fam2_day, daily_occupancy)
            
            # The cost of everything that will change, before the families are switched
            before = accounting_fam1_before_1 + accounting_fam1_before_2 + accounting_fam2_before_1 + accounting_fam2_before_2 + fam1_penalty_pre + fam2_penalty_pre

            # Switch the families by updating the daily occupancy
            daily_occupancy_temp = daily_occupancy.copy()
            daily_occupancy_temp[fam1_day] = daily_occupancy_temp[fam1_day] - family_size_dict[fam_id] + family_size_dict[fam_id2]
            daily_occupancy_temp[fam2_day] = daily_occupancy_temp[fam2_day] - family_size_dict[fam_id2] + family_size_dict[fam_id]

            accounting_fam1_after_1 = accounting_day(fam1_day, daily_occupancy_temp)
            
            if((fam1_day != 1) & (fam1_day - 1 != fam2_day)):
                accounting_fam1_after_2 = accounting_day(fam1_day - 1, daily_occupancy_temp)
            else:
                accounting_fam1_after_2 = 0
                
            accounting_fam2_after_1 = accounting_day(fam2_day, daily_occupancy_temp)
            
            if((fam2_day != 1) & (fam2_day - 1 != fam1_day)):
                accounting_fam2_after_2 = accounting_day(fam2_day - 1, daily_occupancy_temp)
            else:
                accounting_fam2_after_2 = 0
                
            fam1_penalty_post = calc_family_penalty(fam_id, fam2_day, daily_occupancy_temp)
            fam2_penalty_post = calc_family_penalty(fam_id2, fam1_day, daily_occupancy_temp)
            
            # The cost of everything that will change, after the families are switched
            after = accounting_fam1_after_1 + accounting_fam1_after_2 + accounting_fam2_after_1 + accounting_fam2_after_2 + fam1_penalty_post + fam2_penalty_post

            # If the cost decreases, swap them
            if(before > after):
                daily_occupancy = daily_occupancy_temp.copy()
                new[fam_id] = fam2_day
                new[fam_id2] = fam1_day

# %% [markdown]
# Now, we basically just alternate calling these functions until we've reached a point where neither of them can do anything to make the cost smaller.

# %%
import random

# %%
cost = cost_function(new)
i = 0
b = 0
print('Working on minimizing cost')
print(f'current cost: {cost}')
while(True):
    i = i + 1
    change_family_days()
    new_cost = cost_function(new)
    if(new_cost < cost):
        print(f'Round {i}: Changed family days.  New cost: {new_cost}')
        cost = new_cost
        continue
    swap_families()
    new_cost = cost_function(new)
    if(new_cost < cost):
        print(f'Round {i}: Swapped families.  New cost: {new_cost}')
        cost = new_cost
        continue
    else:
        break
# Out:
# Working on minimizing cost
# current cost: 10641498.403135022
# Switching 0 from day 100 to day 1
# Switching 0 from day 1 to day 3
# Switching 0 from day 3 to day 9
# Switching 0 from day 9 to day 10
# Switching 0 from day 10 to day 12
# Switching 0 from day 12 to day 38
# Switching 0 from day 38 to day 52
# Switching 1 from day 99 to day 1
# Switching 1 from day 1 to day 3
# Switching 1 from day 3 to day 4
# Switching 1 from day 4 to day 26
# Switching 2 from day 98 to day 1
# Switching 2 from day 1 to day 3
# Switching 2 from day 3 to day 9
# Switching 2 from day 9 to day 10
# Switching 2 from day 10 to day 12
# Switching 2 from day 12 to day 25
# Switching 2 from day 25 to day 54
# Switching 2 from day 54 to day 100
# Switching 3 from day 97 to day 1
# Switching 3 from day 1 to day 2
# Switching 4 from day 96 to day 1
# Switching 4 from day 1 to day 53
# Switching 5 from day 95 to day 2
# Switching 5 from day 2 to day 3
# Switching 5 from day 3 to day 12
# Switching 5 from day 12 to day 59
# Switching 6 from day 94 to day 1
# Switching 6 from day 1 to day 4
# Switching 6 from day 4 to day 88
# Switching 7 from day 93 to day 1
# Switching 7 from day 1 to day 3
# Switching 7 from day 3 to day 10
# Switching 7 from day 10 to day 11
# Switching 7 from day 11 to day 25
# Switching 8 from day 92 to day 1
# Switching 8 from day 1 to day 18
# Switching 9 from day 91 to day 1
# Switching 10 from day 90 to day 3
# Switching 10 from day 3 to day 5
# Switching 10 from day 5 to day 8
# Switching 10 from day 8 to day 92
# Switching 11 from day 89 to day 2
# Switching 11 from day 2 to day 19
# Switching 12 from day 88 to day 1
# Switching 12 from day 1 to day 52
# Switching 13 from day 87 to day 1
# Switching 13 from day 1 to day 25
# Switching 13 from day 25 to day 52
# Switching 13 from day 52 to day 54
# Switching 14 from day 86 to day 1
# Switching 14 from day 1 to day 16
# Switching 14 from day 16 to day 25
# Switching 14 from day 25 to day 45
# Switching 15 from day 85 to day 1
# Switching 15 from day 1 to day 4
# Switching 15 from day 4 to day 22
# Switching 16 from day 84 to day 1
# Switching 16 from day 1 to day 46
# Switching 17 from day 83 to day 1
# Switching 17 from day 1 to day 3
# Switching 17 from day 3 to day 4
# Switching 17 from day 4 to day 5
# Switching 17 from day 5 to day 47
# Switching 18 from day 82 to day 3
# Switching 18 from day 3 to day 4
# Switching 18 from day 4 to day 10
# Switching 18 from day 10 to day 13
# Switching 18 from day 13 to day 38
# Switching 18 from day 38 to day 74
# Switching 18 from day 74 to day 75
# Switching 19 from day 81 to day 1
# Switching 19 from day 1 to day 3
# Switching 20 from day 80 to day 1
# Switching 20 from day 1 to day 3
# Switching 21 from day 79 to day 1
# Switching 21 from day 1 to day 56
# Switching 22 from day 78 to day 1
# Switching 22 from day 1 to day 33
# Switching 23 from day 77 to day 1
# Switching 23 from day 1 to day 3
# Switching 23 from day 3 to day 11
# Switching 23 from day 11 to day 18
# Switching 23 from day 18 to day 19
# Switching 24 from day 76 to day 1
# Switching 24 from day 1 to day 3
# Switching 24 from day 3 to day 4
# Switching 24 from day 4 to day 24
# Switching 24 from day 24 to day 75
# Switching 25 from day 75 to day 1
# Switching 25 from day 1 to day 3
# Switching 25 from day 3 to day 11
# Switching 25 from day 11 to day 16
# Switching 26 from day 74 to day 1
# Switching 26 from day 1 to day 3
# Switching 26 from day 3 to day 4
# Switching 26 from day 4 to day 58
# Switching 27 from day 73 to day 1
# Switching 27 from day 1 to day 38
# Switching 28 from day 72 to day 1
# Switching 28 from day 1 to day 2
# Switching 28 from day 2 to day 21
# Switching 28 from day 21 to day 27
# Switching 29 from day 71 to day 1
# Switching 29 from day 1 to day 8
# Switching 29 from day 8 to day 89
# Switching 30 from day 70 to day 1
# Switching 30 from day 1 to day 3
# Switching 30 from day 3 to day 5
# Switching 30 from day 5 to day 44
# Switching 30 from day 44 to day 52
# Switching 30 from day 52 to day 53
# Switching 30 from day 53 to day 68
# Switching 31 from day 69 to day 1
# Switching 31 from day 1 to day 3
# Switching 31 from day 3 to day 7
# Switching 31 from day 7 to day 74
# Switching 32 from day 68 to day 1
# Switching 32 from day 1 to day 3
# Switching 32 from day 3 to day 6
# Switching 32 from day 6 to day 9
# Switching 32 from day 9 to day 10
# Switching 32 from day 10 to day 15
# Switching 32 from day 15 to day 24
# Switching 33 from day 67 to day 1
# Switching 33 from day 1 to day 32
# Switching 34 from day 66 to day 1
# Switching 34 from day 1 to day 3
# Switching 34 from day 3 to day 6
# Switching 34 from day 6 to day 9
# Switching 34 from day 9 to day 15
# Switching 34 from day 15 to day 17
# Switching 34 from day 17 to day 40
# Switching 34 from day 40 to day 46
# Switching 35 from day 65 to day 19
# Switching 35 from day 19 to day 31
# Switching 36 from day 64 to day 1
# Switching 36 from day 1 to day 4
# Switching 36 from day 4 to day 33
# Switching 36 from day 33 to day 47
# Switching 37 from day 63 to day 1
# Switching 37 from day 1 to day 3
# Switching 37 from day 3 to day 6
# Switching 37 from day 6 to day 8
# Switching 37 from day 8 to day 15
# Switching 38 from day 62 to day 1
# Switching 38 from day 1 to day 13
# Switching 39 from day 61 to day 1
# Switching 39 from day 1 to day 9
# Switching 40 from day 60 to day 1
# Switching 40 from day 1 to day 6
# Switching 40 from day 6 to day 7
# Switching 40 from day 7 to day 8
# Switching 40 from day 8 to day 25
# Switching 41 from day 59 to day 5
# Switching 41 from day 5 to day 31
# Switching 42 from day 58 to day 1
# Switching 42 from day 1 to day 5
# Switching 42 from day 5 to day 12
# Switching 42 from day 12 to day 45
# Switching 43 from day 57 to day 1
# Switching 43 from day 1 to day 11
# Switching 44 from day 56 to day 1
# Switching 44 from day 1 to day 49
# Switching 45 from day 55 to day 5
# Switching 46 from day 54 to day 1
# Switching 46 from day 1 to day 10
# Switching 46 from day 10 to day 15
# Switching 47 from day 53 to day 1
# Switching 47 from day 1 to day 19
# Switching 47 from day 19 to day 45
# Switching 48 from day 52 to day 5
# Switching 48 from day 5 to day 21
# Switching 49 from day 51 to day 1
# Switching 49 from day 1 to day 3
# Switching 49 from day 3 to day 4
# Switching 49 from day 4 to day 33
# Switching 50 from day 50 to day 67
# Switching 51 from day 49 to day 1
# Switching 51 from day 1 to day 3
# Switching 51 from day 3 to day 6
# Switching 51 from day 6 to day 23
# Switching 51 from day 23 to day 26
# Switching 51 from day 26 to day 28
# Switching 52 from day 48 to day 1
# Switching 52 from day 1 to day 3
# Switching 52 from day 3 to day 4
# Switching 52 from day 4 to day 10
# Switching 52 from day 10 to day 33
# Switching 53 from day 47 to day 1
# Switching 53 from day 1 to day 22
# Switching 53 from day 22 to day 37
# Switching 54 from day 46 to day 1
# Switching 54 from day 1 to day 3
# Switching 54 from day 3 to day 6
# Switching 54 from day 6 to day 25
# Switching 54 from day 25 to day 69
# Switching 54 from day 69 to day 94
# Switching 55 from day 45 to day 2
# Switching 55 from day 2 to day 6
# Switching 55 from day 6 to day 91
# Switching 56 from day 44 to day 1
# Switching 56 from day 1 to day 12
# Switching 57 from day 43 to day 1
# Switching 57 from day 1 to day 31
# Switching 58 from day 42 to day 1
# Switching 58 from day 1 to day 26
# Switching 58 from day 26 to day 32
# Switching 58 from day 32 to day 74
# Switching 59 from day 41 to day 1
# Switching 59 from day 1 to day 3
# Switching 59 from day 3 to day 5
# Switching 59 from day 5 to day 15
# Switching 59 from day 15 to day 39
# Switching 60 from day 40 to day 1
# Switching 61 from day 39 to day 1
# Switching 61 from day 1 to day 3
# Switching 61 from day 3 to day 15
# Switching 61 from day 15 to day 18
# Switching 62 from day 38 to day 1
# Switching 63 from day 37 to day 3
# Switching 63 from day 3 to day 6
# Switching 63 from day 6 to day 14
# Switching 63 from day 14 to day 22
# Switching 63 from day 22 to day 31
# Switching 63 from day 31 to day 73
# Switching 64 from day 36 to day 1
# Switching 64 from day 1 to day 3
# Switching 65 from day 35 to day 1
# Switching 65 from day 1 to day 2
# Switching 65 from day 2 to day 17
# Switching 65 from day 17 to day 20
# Switching 65 from day 20 to day 47
# Switching 66 from day 34 to day 1
# Switching 67 from day 33 to day 1
# Switching 68 from day 32 to day 1
# Switching 68 from day 1 to day 3
# Switching 68 from day 3 to day 6
# Switching 68 from day 6 to day 18
# Switching 68 from day 18 to day 58
# Switching 68 from day 58 to day 78
# Switching 68 from day 78 to day 85
# Switching 68 from day 85 to day 89
# Switching 69 from day 31 to day 1
# Switching 69 from day 1 to day 3
# Switching 69 from day 3 to day 5
# Switching 70 from day 30 to day 1
# Switching 70 from day 1 to day 32
# Switching 71 from day 29 to day 11
# Switching 72 from day 28 to day 1
# Switching 72 from day 1 to day 3
# Switching 72 from day 3 to day 6
# Switching 72 from day 6 to day 26
# Switching 72 from day 26 to day 38
# Switching 72 from day 38 to day 66
# Switching 73 from day 27 to day 1
# Switching 73 from day 1 to day 10
# Switching 74 from day 26 to day 1
# Switching 74 from day 1 to day 3
# Switching 74 from day 3 to day 5
# Switching 74 from day 5 to day 6
# Switching 74 from day 6 to day 28
# Switching 74 from day 28 to day 66
# Switching 74 from day 66 to day 82
# Switching 75 from day 25 to day 1
# Switching 75 from day 1 to day 16
# Switching 75 from day 16 to day 52
# Switching 75 from day 52 to day 53
# Switching 76 from day 24 to day 46
# Switching 77 from day 23 to day 6
# Switching 77 from day 6 to day 12
# Switching 77 from day 12 to day 20
# Switching 78 from day 22 to day 1
# Switching 78 from day 1 to day 3
# Switching 78 from day 3 to day 6
# Switching 78 from day 6 to day 10
# Switching 78 from day 10 to day 25
# Switching 78 from day 25 to day 47
# Switching 78 from day 47 to day 52
# Switching 79 from day 21 to day 1
# Switching 80 from day 20 to day 1
# Switching 80 from day 1 to day 10
# Switching 80 from day 10 to day 18
# Switching 81 from day 19 to day 1
# Switching 81 from day 1 to day 17
# Switching 82 from day 18 to day 1
# Switching 82 from day 1 to day 8
# Switching 82 from day 8 to day 32
# Switching 83 from day 17 to day 1
# Switching 83 from day 1 to day 3
# Switching 83 from day 3 to day 6
# Switching 83 from day 6 to day 12
# Switching 83 from day 12 to day 14
# Switching 83 from day 14 to day 59
# Switching 83 from day 59 to day 88
# Switching 84 from day 16 to day 1
# Switching 84 from day 1 to day 6
# Switching 84 from day 6 to day 9
# Switching 85 from day 15 to day 1
# Switching 85 from day 1 to day 3
# Switching 85 from day 3 to day 5
# Switching 85 from day 5 to day 10
# Switching 85 from day 10 to day 54
# Switching 86 from day 14 to day 1
# Switching 86 from day 1 to day 29
# Switching 87 from day 13 to day 1
# Switching 87 from day 1 to day 3
# Switching 87 from day 3 to day 6
# Switching 87 from day 6 to day 18
# Switching 87 from day 18 to day 25
# Switching 88 from day 12 to day 34
# Switching 88 from day 34 to day 57
# Switching 89 from day 11 to day 1
# Switching 89 from day 1 to day 3
# Switching 89 from day 3 to day 6
# Switching 89 from day 6 to day 12
# Switching 89 from day 12 to day 17
# Switching 89 from day 17 to day 23
# Switching 90 from day 10 to day 1
# Switching 90 from day 1 to day 17
# Switching 90 from day 17 to day 33
# Switching 90 from day 33 to day 52
# Switching 90 from day 52 to day 54
# Switching 91 from day 9 to day 1
# Switching 91 from day 1 to day 17
# Switching 92 from day 8 to day 1
# Switching 92 from day 1 to day 85
# Switching 93 from day 7 to day 1
# Switching 93 from day 1 to day 5
# Switching 93 from day 5 to day 33
# Switching 94 from day 6 to day 1
# Switching 94 from day 1 to day 10
# Switching 94 from day 10 to day 47
# Switching 95 from day 5 to day 1
# Switching 95 from day 1 to day 24
# Switching 96 from day 4 to day 1
# Switching 96 from day 1 to day 75
# Switching 97 from day 3 to day 1
# Switching 97 from day 1 to day 24
# Switching 98 from day 2 to day 1
# Switching 98 from day 1 to day 3
# Switching 99 from day 1 to day 2
# Switching 99 from day 2 to day 3
# Switching 99 from day 3 to day 4
# Switching 99 from day 4 to day 17
# Switching 99 from day 17 to day 18
# Switching 99 from day 18 to day 23
# Switching 99 from day 23 to day 39
# Switching 100 from day 100 to day 1
# Switching 100 from day 1 to day 39
# Switching 101 from day 99 to day 1
# Switching 101 from day 1 to day 9
# Switching 101 from day 9 to day 17
# Switching 101 from day 17 to day 53
# Switching 102 from day 98 to day 1
# Switching 102 from day 1 to day 13
# Switching 102 from day 13 to day 29
# Switching 103 from day 97 to day 4
# Switching 103 from day 4 to day 12
# Switching 103 from day 12 to day 68
# Switching 104 from day 96 to day 1
# Switching 104 from day 1 to day 2
# Switching 104 from day 2 to day 3
# Switching 104 from day 3 to day 33
# Switching 104 from day 33 to day 47
# Switching 105 from day 95 to day 6
# Switching 105 from day 6 to day 12
# Switching 106 from day 94 to day 1
# Switching 106 from day 1 to day 2
# Switching 106 from day 2 to day 3
# Switching 106 from day 3 to day 17
# Switching 106 from day 17 to day 30
# Switching 106 from day 30 to day 34
# Switching 107 from day 93 to day 6
# Switching 107 from day 6 to day 12
# Switching 108 from day 92 to day 1
# Switching 108 from day 1 to day 32
# Switching 108 from day 32 to day 34
# Switching 109 from day 91 to day 1
# Switching 109 from day 1 to day 2
# Switching 109 from day 2 to day 3
# Switching 109 from day 3 to day 4
# Switching 109 from day 4 to day 6
# Switching 109 from day 6 to day 9
# Switching 109 from day 9 to day 17
# Switching 109 from day 17 to day 75
# Switching 110 from day 90 to day 1
# Switching 110 from day 1 to day 9
# Switching 110 from day 9 to day 22
# Switching 110 from day 22 to day 67
# Switching 111 from day 89 to day 1
# Switching 111 from day 1 to day 68
# Switching 112 from day 88 to day 4
# Switching 112 from day 4 to day 6
# Switching 112 from day 6 to day 13
# Switching 112 from day 13 to day 60
# Switching 113 from day 87 to day 1
# Switching 113 from day 1 to day 18
# Switching 114 from day 86 to day 4
# Switching 114 from day 4 to day 5
# Switching 114 from day 5 to day 15
# Switching 115 from day 85 to day 1
# Switching 115 from day 1 to day 17
# Switching 115 from day 17 to day 22
# Switching 116 from day 84 to day 3
# Switching 116 from day 3 to day 4
# Switching 116 from day 4 to day 6
# Switching 116 from day 6 to day 12
# Switching 116 from day 12 to day 19
# Switching 116 from day 19 to day 77
# Switching 117 from day 83 to day 1
# Switching 117 from day 1 to day 94
# Switching 118 from day 82 to day 4
# Switching 118 from day 4 to day 11
# Switching 118 from day 11 to day 16
# Switching 118 from day 16 to day 69
# Switching 119 from day 81 to day 1
# Switching 119 from day 1 to day 2
# Switching 119 from day 2 to day 3
# Switching 119 from day 3 to day 4
# Switching 120 from day 80 to day 27
# Switching 120 from day 27 to day 28
# Switching 120 from day 28 to day 56
# Switching 121 from day 79 to day 1
# Switching 121 from day 1 to day 2
# Switching 121 from day 2 to day 3
# Switching 121 from day 3 to day 4
# Switching 121 from day 4 to day 17
# Switching 122 from day 78 to day 1
# Switching 122 from day 1 to day 4
# Switching 122 from day 4 to day 24
# Switching 123 from day 77 to day 2
# Switching 123 from day 2 to day 3
# Switching 123 from day 3 to day 4
# Switching 123 from day 4 to day 18
# Switching 123 from day 18 to day 22
# Switching 123 from day 22 to day 95
# Switching 124 from day 76 to day 1
# Switching 124 from day 1 to day 7
# Switching 124 from day 7 to day 14
# Switching 125 from day 75 to day 1
# Switching 125 from day 1 to day 3
# Switching 125 from day 3 to day 8
# Switching 125 from day 8 to day 47
# Switching 126 from day 74 to day 1
# Switching 126 from day 1 to day 2
# Switching 126 from day 2 to day 3
# Switching 127 from day 73 to day 2
# Switching 128 from day 72 to day 12
# Switching 128 from day 12 to day 56
# Switching 129 from day 71 to day 3
# Switching 129 from day 3 to day 4
# Switching 129 from day 4 to day 6
# Switching 129 from day 6 to day 14
# Switching 129 from day 14 to day 17
# Switching 129 from day 17 to day 43
# Switching 130 from day 70 to day 1
# Switching 130 from day 1 to day 16
# Switching 131 from day 69 to day 3
# Switching 131 from day 3 to day 4
# Switching 131 from day 4 to day 5
# Switching 131 from day 5 to day 9
# Switching 131 from day 9 to day 11
# Switching 132 from day 68 to day 1
# Switching 132 from day 1 to day 3
# Switching 132 from day 3 to day 24
# Switching 132 from day 24 to day 36
# Switching 132 from day 36 to day 74
# Switching 132 from day 74 to day 76
# Switching 133 from day 67 to day 4
# Switching 133 from day 4 to day 5
# Switching 133 from day 5 to day 14
# Switching 133 from day 14 to day 20
# Switching 133 from day 20 to day 40
# Switching 133 from day 40 to day 54
# Switching 134 from day 66 to day 1
# Switching 134 from day 1 to day 17
# Switching 134 from day 17 to day 18
# Switching 135 from day 65 to day 1
# Switching 135 from day 1 to day 2
# Switching 135 from day 2 to day 5
# Switching 135 from day 5 to day 18
# Switching 135 from day 18 to day 33
# Switching 136 from day 64 to day 1
# Switching 136 from day 1 to day 88
# Switching 137 from day 63 to day 1
# Switching 137 from day 1 to day 8
# Switching 137 from day 8 to day 26
# Switching 137 from day 26 to day 82
# Switching 138 from day 62 to day 2
# Switching 138 from day 2 to day 59
# Switching 139 from day 61 to day 1
# Switching 139 from day 1 to day 3
# Switching 139 from day 3 to day 4
# Switching 139 from day 4 to day 6
# Switching 139 from day 6 to day 8
# Switching 139 from day 8 to day 11
# Switching 139 from day 11 to day 89
# Switching 140 from day 60 to day 1
# Switching 141 from day 59 to day 3
# Switching 141 from day 3 to day 4
# Switching 141 from day 4 to day 89
# Switching 142 from day 58 to day 1
# Switching 142 from day 1 to day 3
# Switching 142 from day 3 to day 4
# Switching 142 from day 4 to day 6
# Switching 142 from day 6 to day 10
# Switching 142 from day 10 to day 26
# Switching 143 from day 57 to day 1
# Switching 143 from day 1 to day 17
# Switching 143 from day 17 to day 28
# Switching 143 from day 28 to day 38
# Switching 144 from day 56 to day 1
# Switching 144 from day 1 to day 5
# Switching 144 from day 5 to day 12
# Switching 144 from day 12 to day 28
# Switching 145 from day 55 to day 6
# Switching 145 from day 6 to day 10
# Switching 145 from day 10 to day 18
# Switching 146 from day 54 to day 1
# Switching 146 from day 1 to day 3
# Switching 146 from day 3 to day 4
# Switching 146 from day 4 to day 6
# Switching 146 from day 6 to day 24
# Switching 146 from day 24 to day 36
# Switching 146 from day 36 to day 42
# Switching 146 from day 42 to day 64
# Switching 147 from day 53 to day 1
# Switching 147 from day 1 to day 7
# Switching 147 from day 7 to day 24
# Switching 147 from day 24 to day 28
# Switching 148 from day 52 to day 3
# Switching 148 from day 3 to day 4
# Switching 148 from day 4 to day 25
# Switching 148 from day 25 to day 63
# Switching 149 from day 51 to day 1
# Switching 149 from day 1 to day 18
# Switching 149 from day 18 to day 38
# Switching 149 from day 38 to day 40
# Switching 150 from day 50 to day 3
# Switching 150 from day 3 to day 4
# Switching 150 from day 4 to day 6
# Switching 150 from day 6 to day 12
# Switching 150 from day 12 to day 19
# Switching 150 from day 19 to day 60
# Switching 151 from day 49 to day 2
# Switching 151 from day 2 to day 3
# Switching 152 from day 48 to day 1
# Switching 152 from day 1 to day 40
# Switching 152 from day 40 to day 88
# Switching 153 from day 47 to day 1
# Switching 153 from day 1 to day 2
# Switching 153 from day 2 to day 3
# Switching 154 from day 46 to day 1
# Switching 154 from day 1 to day 2
# Switching 154 from day 2 to day 4
# Switching 154 from day 4 to day 6
# Switching 154 from day 6 to day 18
# Switching 154 from day 18 to day 25
# Switching 155 from day 45 to day 1
# Switching 155 from day 1 to day 27
# Switching 155 from day 27 to day 100
# Switching 156 from day 44 to day 74
# Switching 156 from day 74 to day 95
# Switching 157 from day 43 to day 4
# Switching 157 from day 4 to day 9
# Switching 157 from day 9 to day 29
# Switching 157 from day 29 to day 54
# Switching 157 from day 54 to day 61
# Switching 157 from day 61 to day 87
# Switching 158 from day 42 to day 1
# Switching 158 from day 1 to day 3
# Switching 158 from day 3 to day 13
# Switching 159 from day 41 to day 1
# Switching 159 from day 1 to day 2
# Switching 159 from day 2 to day 3
# Switching 161 from day 39 to day 1
# Switching 161 from day 1 to day 43
# Switching 161 from day 43 to day 47
# Switching 162 from day 38 to day 4
# Switching 162 from day 4 to day 6
# Switching 162 from day 6 to day 15
# Switching 162 from day 15 to day 68
# Switching 163 from day 37 to day 4
# Switching 163 from day 4 to day 5
# Switching 163 from day 5 to day 15
# Switching 163 from day 15 to day 30
# Switching 163 from day 30 to day 84
# Switching 164 from day 36 to day 1
# Switching 164 from day 1 to day 18
# Switching 165 from day 35 to day 1
# Switching 166 from day 34 to day 2
# Switching 166 from day 2 to day 4
# Switching 166 from day 4 to day 6
# Switching 166 from day 6 to day 14
# Switching 167 from day 33 to day 1
# Switching 167 from day 1 to day 93
# Switching 167 from day 93 to day 95
# Switching 168 from day 32 to day 1
# Switching 168 from day 1 to day 2
# Switching 168 from day 2 to day 3
# Switching 168 from day 3 to day 13
# Switching 168 from day 13 to day 19
# Switching 169 from day 31 to day 1
# Switching 169 from day 1 to day 2
# Switching 169 from day 2 to day 4
# Switching 169 from day 4 to day 5
# Switching 169 from day 5 to day 17
# Switching 169 from day 17 to day 67
# Switching 170 from day 30 to day 1
# Switching 170 from day 1 to day 10
# Switching 170 from day 10 to day 12
# Switching 171 from day 29 to day 1
# Switching 171 from day 1 to day 24
# Switching 172 from day 28 to day 1
# Switching 172 from day 1 to day 15
# Switching 172 from day 15 to day 21
# Switching 173 from day 27 to day 1
# Switching 173 from day 1 to day 24
# Switching 173 from day 24 to day 38
# Switching 173 from day 38 to day 47
# Switching 173 from day 47 to day 55
# Switching 173 from day 55 to day 68
# Switching 174 from day 26 to day 2
# Switching 174 from day 2 to day 3
# Switching 174 from day 3 to day 13
# Switching 174 from day 13 to day 18
# Switching 174 from day 18 to day 34
# Switching 174 from day 34 to day 94
# Switching 175 from day 25 to day 2
# Switching 175 from day 2 to day 4
# Switching 175 from day 4 to day 6
# Switching 175 from day 6 to day 17
# Switching 176 from day 24 to day 1
# Switching 176 from day 1 to day 2
# Switching 176 from day 2 to day 4
# Switching 176 from day 4 to day 16
# Switching 176 from day 16 to day 18
# Switching 176 from day 18 to day 52
# Switching 177 from day 23 to day 6
# Switching 177 from day 6 to day 13
# Switching 177 from day 13 to day 74
# Switching 178 from day 22 to day 1
# Switching 178 from day 1 to day 45
# Switching 178 from day 45 to day 80
# Switching 179 from day 21 to day 1
# Switching 179 from day 1 to day 2
# Switching 179 from day 2 to day 26
# Switching 180 from day 20 to day 40
# Switching 181 from day 19 to day 1
# Switching 181 from day 1 to day 7
# Switching 182 from day 18 to day 2
# Switching 182 from day 2 to day 4
# Switching 182 from day 4 to day 6
# Switching 182 from day 6 to day 8
# Switching 182 from day 8 to day 12
# Switching 182 from day 12 to day 87
# Switching 182 from day 87 to day 94
# Switching 184 from day 16 to day 1
# Switching 184 from day 1 to day 4
# Switching 185 from day 15 to day 1
# Switching 185 from day 1 to day 31
# Switching 185 from day 31 to day 80
# Switching 186 from day 14 to day 1
# Switching 186 from day 1 to day 2
# Switching 186 from day 2 to day 50
# Switching 187 from day 13 to day 1
# Switching 187 from day 1 to day 26
# Switching 187 from day 26 to day 39
# Switching 187 from day 39 to day 43
# Switching 188 from day 12 to day 6
# Switching 188 from day 6 to day 10
# Switching 189 from day 11 to day 1
# Switching 190 from day 10 to day 1
# Switching 190 from day 1 to day 9
# Switching 191 from day 9 to day 1
# Switching 191 from day 1 to day 5
# Switching 191 from day 5 to day 33
# Switching 191 from day 33 to day 54
# Switching 192 from day 8 to day 2
# Switching 192 from day 2 to day 4
# Switching 192 from day 4 to day 6
# Switching 192 from day 6 to day 13
# Switching 192 from day 13 to day 20
# Switching 192 from day 20 to day 33
# Switching 192 from day 33 to day 77
# Switching 193 from day 7 to day 2
# Switching 193 from day 2 to day 4
# Switching 193 from day 4 to day 6
# Switching 193 from day 6 to day 12
# Switching 194 from day 6 to day 1
# Switching 194 from day 1 to day 95
# Switching 195 from day 5 to day 1
# Switching 195 from day 1 to day 9
# Switching 195 from day 9 to day 55
# Switching 196 from day 4 to day 6
# Switching 196 from day 6 to day 7
# Switching 196 from day 7 to day 26
# Switching 197 from day 3 to day 1
# Switching 197 from day 1 to day 18
# Switching 197 from day 18 to day 19
# Switching 197 from day 19 to day 44
# Switching 197 from day 44 to day 59
# Switching 198 from day 2 to day 1
# Switching 198 from day 1 to day 31
# Switching 198 from day 31 to day 59
# Switching 198 from day 59 to day 81
# Switching 198 from day 81 to day 90
# Switching 199 from day 1 to day 8
# Switching 199 from day 8 to day 22
# Switching 199 from day 22 to day 31
# Switching 199 from day 31 to day 51
# Switching 200 from day 100 to day 1
# Switching 200 from day 1 to day 26
# Switching 201 from day 99 to day 2
# Switching 201 from day 2 to day 5
# Switching 201 from day 5 to day 21
# Switching 201 from day 21 to day 35
# Switching 202 from day 98 to day 2
# Switching 202 from day 2 to day 6
# Switching 202 from day 6 to day 23
# Switching 203 from day 97 to day 3
# Switching 203 from day 3 to day 38
# Switching 204 from day 96 to day 1
# Switching 204 from day 1 to day 2
# Switching 204 from day 2 to day 6
# Switching 204 from day 6 to day 17
# Switching 204 from day 17 to day 45
# Switching 204 from day 45 to day 67
# Switching 205 from day 95 to day 1
# Switching 206 from day 94 to day 1
# Switching 206 from day 1 to day 18
# Switching 206 from day 18 to day 28
# Switching 207 from day 93 to day 5
# Switching 207 from day 5 to day 47
# Switching 208 from day 92 to day 1
# Switching 209 from day 91 to day 2
# Switching 209 from day 2 to day 3
# Switching 209 from day 3 to day 9
# Switching 210 from day 90 to day 1
# Switching 210 from day 1 to day 23
# Switching 211 from day 89 to day 1
# Switching 211 from day 1 to day 9
# Switching 211 from day 9 to day 45
# Switching 211 from day 45 to day 67
# Switching 212 from day 88 to day 1
# Switching 212 from day 1 to day 3
# Switching 212 from day 3 to day 10
# Switching 213 from day 87 to day 1
# Switching 213 from day 1 to day 18
# Switching 213 from day 18 to day 52
# Switching 214 from day 86 to day 2
# Switching 214 from day 2 to day 3
# Switching 214 from day 3 to day 18
# Switching 214 from day 18 to day 31
# Switching 215 from day 85 to day 1
# Switching 216 from day 84 to day 2
# Switching 216 from day 2 to day 5
# Switching 216 from day 5 to day 43
# Switching 217 from day 83 to day 2
# Switching 217 from day 2 to day 4
# Switching 217 from day 4 to day 5
# Switching 217 from day 5 to day 38
# Switching 218 from day 82 to day 1
# Switching 218 from day 1 to day 23
# Switching 218 from day 23 to day 38
# Switching 219 from day 81 to day 31
# Switching 219 from day 31 to day 68
# Switching 220 from day 80 to day 1
# Switching 221 from day 79 to day 1
# Switching 221 from day 1 to day 4
# Switching 222 from day 78 to day 1
# Switching 222 from day 1 to day 12
# Switching 222 from day 12 to day 19
# Switching 222 from day 19 to day 36
# Switching 223 from day 77 to day 1
# Switching 223 from day 1 to day 5
# Switching 223 from day 5 to day 60
# Switching 224 from day 76 to day 2
# Switching 224 from day 2 to day 3
# Switching 224 from day 3 to day 4
# Switching 225 from day 75 to day 2
# Switching 225 from day 2 to day 5
# Switching 225 from day 5 to day 11
# Switching 225 from day 11 to day 24
# Switching 225 from day 24 to day 61
# Switching 226 from day 74 to day 1
# Switching 226 from day 1 to day 3
# Switching 226 from day 3 to day 17
# Switching 226 from day 17 to day 59
# Switching 227 from day 73 to day 1
# Switching 227 from day 1 to day 16
# Switching 227 from day 16 to day 39
# Switching 227 from day 39 to day 49
# Switching 228 from day 72 to day 1
# Switching 228 from day 1 to day 4
# Switching 228 from day 4 to day 25
# Switching 228 from day 25 to day 87
# Switching 229 from day 71 to day 1
# Switching 229 from day 1 to day 48
# Switching 230 from day 70 to day 2
# Switching 230 from day 2 to day 31
# Switching 230 from day 31 to day 35
# Switching 230 from day 35 to day 57
# Switching 231 from day 69 to day 1
# Switching 231 from day 1 to day 4
# Switching 231 from day 4 to day 48
# Switching 232 from day 68 to day 1
# Switching 232 from day 1 to day 26
# Switching 232 from day 26 to day 47
# Switching 233 from day 67 to day 1
# Switching 233 from day 1 to day 12
# Switching 233 from day 12 to day 45
# Switching 233 from day 45 to day 87
# Switching 234 from day 66 to day 82
# Switching 235 from day 65 to day 2
# Switching 235 from day 2 to day 3
# Switching 235 from day 3 to day 10
# Switching 235 from day 10 to day 13
# Switching 235 from day 13 to day 53
# Switching 236 from day 64 to day 2
# Switching 236 from day 2 to day 8
# Switching 236 from day 8 to day 37
# Switching 237 from day 63 to day 2
# Switching 237 from day 2 to day 3
# Switching 238 from day 62 to day 4
# Switching 238 from day 4 to day 19
# Switching 239 from day 61 to day 1
# Switching 239 from day 1 to day 3
# Switching 239 from day 3 to day 13
# Switching 239 from day 13 to day 14
# Switching 240 from day 60 to day 1
# Switching 240 from day 1 to day 21
# Switching 240 from day 21 to day 33
# Switching 241 from day 59 to day 1
# Switching 241 from day 1 to day 4
# Switching 241 from day 4 to day 25
# Switching 241 from day 25 to day 52
# Switching 241 from day 52 to day 60
# Switching 242 from day 58 to day 1
# Switching 242 from day 1 to day 15
# Switching 242 from day 15 to day 17
# Switching 242 from day 17 to day 60
# Switching 243 from day 57 to day 1
# Switching 243 from day 1 to day 4
# Switching 243 from day 4 to day 89
# Switching 244 from day 56 to day 2
# Switching 244 from day 2 to day 17
# Switching 244 from day 17 to day 18
# Switching 244 from day 18 to day 35
# Switching 244 from day 35 to day 39
# Switching 245 from day 55 to day 2
# Switching 245 from day 2 to day 3
# Switching 245 from day 3 to day 4
# Switching 246 from day 54 to day 2
# Switching 246 from day 2 to day 7
# Switching 246 from day 7 to day 22
# Switching 246 from day 22 to day 30
# Switching 246 from day 30 to day 50
# Switching 247 from day 53 to day 2
# Switching 247 from day 2 to day 24
# Switching 247 from day 24 to day 66
# Switching 248 from day 52 to day 2
# Switching 248 from day 2 to day 5
# Switching 248 from day 5 to day 22
# Switching 248 from day 22 to day 33
# Switching 249 from day 51 to day 1
# Switching 249 from day 1 to day 14
# Switching 249 from day 14 to day 75
# Switching 250 from day 50 to day 1
# Switching 250 from day 1 to day 7
# Switching 251 from day 49 to day 2
# Switching 251 from day 2 to day 9
# Switching 251 from day 9 to day 44
# Switching 251 from day 44 to day 66
# Switching 251 from day 66 to day 75
# Switching 252 from day 48 to day 1
# Switching 252 from day 1 to day 18
# Switching 253 from day 47 to day 2
# Switching 253 from day 2 to day 6
# Switching 253 from day 6 to day 24
# Switching 253 from day 24 to day 32
# Switching 253 from day 32 to day 73
# Switching 254 from day 46 to day 2
# Switching 254 from day 2 to day 6
# Switching 254 from day 6 to day 18
# Switching 255 from day 45 to day 1
# Switching 255 from day 1 to day 12
# Switching 256 from day 44 to day 2
# Switching 256 from day 2 to day 12
# Switching 256 from day 12 to day 17
# Switching 256 from day 17 to day 31
# Switching 256 from day 31 to day 32
# Switching 256 from day 32 to day 74
# Switching 256 from day 74 to day 93
# Switching 257 from day 43 to day 1
# Switching 257 from day 1 to day 25
# Switching 257 from day 25 to day 59
# Switching 257 from day 59 to day 74
# Switching 258 from day 42 to day 2
# Switching 258 from day 2 to day 5
# Switching 258 from day 5 to day 11
# Switching 258 from day 11 to day 48
# Switching 258 from day 48 to day 86
# Switching 258 from day 86 to day 92
# Switching 259 from day 41 to day 1
# Switching 259 from day 1 to day 12
# Switching 259 from day 12 to day 60
# Switching 260 from day 40 to day 2
# Switching 260 from day 2 to day 5
# Switching 260 from day 5 to day 20
# Switching 260 from day 20 to day 25
# Switching 261 from day 39 to day 2
# Switching 261 from day 2 to day 22
# Switching 261 from day 22 to day 67
# Switching 262 from day 38 to day 1
# Switching 262 from day 1 to day 5
# Switching 262 from day 5 to day 32
# Switching 263 from day 37 to day 1
# Switching 263 from day 1 to day 19
# Switching 263 from day 19 to day 48
# Switching 264 from day 36 to day 2
# Switching 264 from day 2 to day 10
# Switching 264 from day 10 to day 11
# Switching 265 from day 35 to day 2
# Switching 265 from day 2 to day 11
# Switching 266 from day 34 to day 1
# Switching 266 from day 1 to day 7
# Switching 266 from day 7 to day 32
# Switching 267 from day 33 to day 1
# Switching 267 from day 1 to day 18
# Switching 268 from day 32 to day 1
# Switching 268 from day 1 to day 39
# Switching 269 from day 31 to day 1
# Switching 269 from day 1 to day 16
# Switching 269 from day 16 to day 20
# Switching 269 from day 20 to day 30
# Switching 270 from day 30 to day 2
# Switching 270 from day 2 to day 5
# Switching 270 from day 5 to day 15
# Switching 270 from day 15 to day 31
# Switching 270 from day 31 to day 67
# Switching 271 from day 29 to day 1
# Switching 271 from day 1 to day 3
# Switching 271 from day 3 to day 73
# Switching 272 from day 28 to day 1
# Switching 272 from day 1 to day 23
# Switching 272 from day 23 to day 24
# Switching 272 from day 24 to day 29
# Switching 272 from day 29 to day 31
# Switching 272 from day 31 to day 43
# Switching 273 from day 27 to day 1
# Switching 273 from day 1 to day 38
# Switching 274 from day 26 to day 2
# Switching 274 from day 2 to day 8
# Switching 275 from day 25 to day 3
# Switching 275 from day 3 to day 13
# Switching 275 from day 13 to day 15
# Switching 276 from day 24 to day 2
# Switching 276 from day 2 to day 10
# Switching 276 from day 10 to day 32
# Switching 277 from day 23 to day 1
# Switching 277 from day 1 to day 3
# Switching 278 from day 22 to day 6
# Switching 278 from day 6 to day 46
# Switching 278 from day 46 to day 54
# Switching 279 from day 21 to day 2
# Switching 279 from day 2 to day 11
# Switching 279 from day 11 to day 17
# Switching 279 from day 17 to day 38
# Switching 280 from day 20 to day 2
# Switching 280 from day 2 to day 5
# Switching 280 from day 5 to day 23
# Switching 281 from day 19 to day 18
# Switching 281 from day 18 to day 22
# Switching 282 from day 18 to day 2
# Switching 282 from day 2 to day 4
# Switching 282 from day 4 to day 12
# Switching 282 from day 12 to day 17
# Switching 283 from day 17 to day 1
# Switching 283 from day 1 to day 9
# Switching 283 from day 9 to day 73
# Switching 284 from day 16 to day 2
# Switching 284 from day 2 to day 3
# Switching 284 from day 3 to day 6
# Switching 284 from day 6 to day 20
# Switching 285 from day 15 to day 2
# Switching 285 from day 2 to day 5
# Switching 285 from day 5 to day 66
# Switching 286 from day 14 to day 1
# Switching 286 from day 1 to day 12
# Switching 286 from day 12 to day 22
# Switching 286 from day 22 to day 26
# Switching 286 from day 26 to day 38
# Switching 286 from day 38 to day 54
# Switching 287 from day 13 to day 1
# Switching 287 from day 1 to day 8
# Switching 287 from day 8 to day 47
# Switching 288 from day 12 to day 1
# Switching 288 from day 1 to day 5
# Switching 288 from day 5 to day 16
# Switching 288 from day 16 to day 63
# Switching 289 from day 11 to day 26
# Switching 289 from day 26 to day 66
# Switching 290 from day 10 to day 2
# Switching 290 from day 2 to day 5
# Switching 290 from day 5 to day 25
# Switching 291 from day 9 to day 2
# Switching 291 from day 2 to day 3
# Switching 291 from day 3 to day 11
# Switching 291 from day 11 to day 22
# Switching 291 from day 22 to day 23
# Switching 291 from day 23 to day 80
# Switching 292 from day 8 to day 2
# Switching 292 from day 2 to day 19
# Switching 292 from day 19 to day 66
# Switching 293 from day 7 to day 2
# Switching 293 from day 2 to day 12
# Switching 293 from day 12 to day 18
# Switching 293 from day 18 to day 23
# Switching 293 from day 23 to day 67
# Switching 294 from day 6 to day 1
# Switching 294 from day 1 to day 4
# Switching 294 from day 4 to day 46
# Switching 295 from day 5 to day 2
# Switching 295 from day 2 to day 10
# Switching 296 from day 4 to day 2
# Switching 296 from day 2 to day 10
# Switching 296 from day 10 to day 31
# Switching 296 from day 31 to day 39
# Switching 297 from day 3 to day 1
# Switching 297 from day 1 to day 35
# Switching 297 from day 35 to day 48
# Switching 298 from day 2 to day 8
# Switching 298 from day 8 to day 13
# Switching 298 from day 13 to day 19
# Switching 299 from day 1 to day 10
# Switching 299 from day 10 to day 17
# Switching 299 from day 17 to day 32
# Switching 300 from day 100 to day 1
# Switching 300 from day 1 to day 5
# Switching 301 from day 99 to day 2
# Switching 301 from day 2 to day 11
# Switching 301 from day 11 to day 19
# Switching 301 from day 19 to day 45
# Switching 302 from day 98 to day 2
# Switching 302 from day 2 to day 4
# Switching 303 from day 97 to day 1
# Switching 303 from day 1 to day 13
# Switching 303 from day 13 to day 27
# Switching 304 from day 96 to day 1
# Switching 304 from day 1 to day 19
# Switching 304 from day 19 to day 28
# Switching 304 from day 28 to day 86
# Switching 305 from day 95 to day 1
# Switching 305 from day 1 to day 12
# Switching 305 from day 12 to day 58
# Switching 306 from day 94 to day 2
# Switching 307 from day 93 to day 1
# Switching 308 from day 92 to day 1
# Switching 308 from day 1 to day 10
# Switching 308 from day 10 to day 47
# Switching 309 from day 91 to day 2
# Switching 309 from day 2 to day 4
# Switching 309 from day 4 to day 19
# Switching 310 from day 90 to day 2
# Switching 310 from day 2 to day 11
# Switching 310 from day 11 to day 60
# Switching 310 from day 60 to day 64
# Switching 310 from day 64 to day 89
# Switching 311 from day 89 to day 2
# Switching 311 from day 2 to day 8
# Switching 311 from day 8 to day 59
# Switching 312 from day 88 to day 1
# Switching 312 from day 1 to day 5
# Switching 312 from day 5 to day 43
# Switching 313 from day 87 to day 1
# Switching 313 from day 1 to day 12
# Switching 313 from day 12 to day 17
# Switching 313 from day 17 to day 37
# Switching 314 from day 86 to day 1
# Switching 314 from day 1 to day 4
# Switching 314 from day 4 to day 39
# Switching 315 from day 85 to day 2
# Switching 315 from day 2 to day 9
# Switching 315 from day 9 to day 17
# Switching 315 from day 17 to day 45
# Switching 316 from day 84 to day 2
# Switching 316 from day 2 to day 52
# Switching 316 from day 52 to day 53
# Switching 317 from day 83 to day 2
# Switching 317 from day 2 to day 25
# Switching 318 from day 82 to day 4
# Switching 318 from day 4 to day 49
# Switching 319 from day 81 to day 10
# Switching 320 from day 80 to day 1
# Switching 320 from day 1 to day 7
# Switching 321 from day 79 to day 1
# Switching 321 from day 1 to day 53
# Switching 321 from day 53 to day 95
# Switching 322 from day 78 to day 2
# Switching 322 from day 2 to day 14
# Switching 322 from day 14 to day 53
# Switching 322 from day 53 to day 82
# Switching 323 from day 77 to day 1
# Switching 323 from day 1 to day 15
# Switching 323 from day 15 to day 17
# Switching 323 from day 17 to day 48
# Switching 324 from day 76 to day 1
# Switching 324 from day 1 to day 33
# Switching 325 from day 75 to day 1
# Switching 326 from day 74 to day 2
# Switching 326 from day 2 to day 14
# Switching 326 from day 14 to day 22
# Switching 326 from day 22 to day 26
# Switching 327 from day 73 to day 1
# Switching 327 from day 1 to day 14
# Switching 327 from day 14 to day 46
# Switching 328 from day 72 to day 1
# Switching 328 from day 1 to day 6
# Switching 328 from day 6 to day 10
# Switching 329 from day 71 to day 1
# Switching 329 from day 1 to day 19
# Switching 330 from day 70 to day 1
# Switching 330 from day 1 to day 4
# Switching 330 from day 4 to day 82
# Switching 331 from day 69 to day 1
# Switching 331 from day 1 to day 17
# Switching 332 from day 68 to day 1
# Switching 332 from day 1 to day 10
# Switching 333 from day 67 to day 1
# Switching 333 from day 1 to day 3
# Switching 333 from day 3 to day 23
# Switching 334 from day 66 to day 2
# Switching 334 from day 2 to day 6
# Switching 334 from day 6 to day 22
# Switching 335 from day 65 to day 1
# Switching 335 from day 1 to day 30
# Switching 335 from day 30 to day 68
# Switching 336 from day 64 to day 1
# Switching 336 from day 1 to day 38
# Switching 336 from day 38 to day 80
# Switching 337 from day 63 to day 1
# Switching 337 from day 1 to day 18
# Switching 337 from day 18 to day 24
# Switching 338 from day 62 to day 2
# Switching 338 from day 2 to day 3
# Switching 338 from day 3 to day 35
# Switching 338 from day 35 to day 53
# Switching 338 from day 53 to day 74
# Switching 339 from day 61 to day 1
# Switching 339 from day 1 to day 22
# Switching 339 from day 22 to day 29
# Switching 339 from day 29 to day 45
# Switching 340 from day 60 to day 1
# Switching 340 from day 1 to day 13
# Switching 341 from day 59 to day 1
# Switching 341 from day 1 to day 12
# Switching 341 from day 12 to day 31
# Switching 341 from day 31 to day 58
# Switching 342 from day 58 to day 2
# Switching 342 from day 2 to day 5
# Switching 342 from day 5 to day 28
# Switching 342 from day 28 to day 54
# Switching 343 from day 57 to day 2
# Switching 343 from day 2 to day 4
# Switching 343 from day 4 to day 33
# Switching 343 from day 33 to day 88
# Switching 344 from day 56 to day 1
# Switching 344 from day 1 to day 23
# Switching 345 from day 55 to day 2
# Switching 345 from day 2 to day 19
# Switching 345 from day 19 to day 26
# Switching 345 from day 26 to day 33
# Switching 345 from day 33 to day 45
# Switching 345 from day 45 to day 66
# Switching 346 from day 54 to day 1
# Switching 346 from day 1 to day 24
# Switching 347 from day 53 to day 1
# Switching 347 from day 1 to day 11
# Switching 347 from day 11 to day 59
# Switching 348 from day 52 to day 1
# Switching 349 from day 51 to day 1
# Switching 349 from day 1 to day 19
# Switching 350 from day 50 to day 1
# Switching 350 from day 1 to day 2
# Switching 350 from day 2 to day 24
# Switching 350 from day 24 to day 27
# Switching 350 from day 27 to day 74
# Switching 351 from day 49 to day 2
# Switching 351 from day 2 to day 27
# Switching 352 from day 48 to day 1
# Switching 352 from day 1 to day 17
# Switching 352 from day 17 to day 55
# Switching 352 from day 55 to day 93
# Switching 353 from day 47 to day 1
# Switching 353 from day 1 to day 4
# Switching 353 from day 4 to day 25
# Switching 354 from day 46 to day 27
# Switching 354 from day 27 to day 87
# Switching 355 from day 45 to day 2
# Switching 355 from day 2 to day 53
# Switching 356 from day 44 to day 1
# Switching 356 from day 1 to day 17
# Switching 356 from day 17 to day 33
# Switching 357 from day 43 to day 1
# Switching 357 from day 1 to day 4
# Switching 357 from day 4 to day 18
# Switching 357 from day 18 to day 25
# Switching 358 from day 42 to day 1
# Switching 358 from day 1 to day 11
# Switching 359 from day 41 to day 2
# Switching 359 from day 2 to day 4
# Switching 359 from day 4 to day 90
# Switching 360 from day 40 to day 1
# Switching 360 from day 1 to day 7
# Switching 360 from day 7 to day 10
# Switching 360 from day 10 to day 55
# Switching 361 from day 39 to day 1
# Switching 361 from day 1 to day 34
# Switching 361 from day 34 to day 87
# Switching 362 from day 38 to day 2
# Switching 362 from day 2 to day 9
# Switching 362 from day 9 to day 40
# Switching 362 from day 40 to day 61
# Switching 362 from day 61 to day 81
# Switching 363 from day 37 to day 1
# Switching 363 from day 1 to day 12
# Switching 364 from day 36 to day 1
# Switching 364 from day 1 to day 12
# Switching 364 from day 12 to day 21
# Switching 364 from day 21 to day 99
# Switching 365 from day 35 to day 2
# Switching 365 from day 2 to day 4
# Switching 366 from day 34 to day 2
# Switching 366 from day 2 to day 3
# Switching 366 from day 3 to day 93
# Switching 367 from day 33 to day 2
# Switching 367 from day 2 to day 11
# Switching 367 from day 11 to day 17
# Switching 368 from day 32 to day 1
# Switching 368 from day 1 to day 26
# Switching 369 from day 31 to day 1
# Switching 369 from day 1 to day 38
# Switching 369 from day 38 to day 45
# Switching 370 from day 30 to day 2
# Switching 370 from day 2 to day 4
# Switching 370 from day 4 to day 13
# Switching 371 from day 29 to day 1
# Switching 371 from day 1 to day 18
# Switching 371 from day 18 to day 20
# Switching 371 from day 20 to day 26
# Switching 372 from day 28 to day 2
# Switching 372 from day 2 to day 11
# Switching 372 from day 11 to day 25
# Switching 372 from day 25 to day 96
# Switching 372 from day 96 to day 98
# Switching 373 from day 27 to day 2
# Switching 374 from day 26 to day 1
# Switching 374 from day 1 to day 5
# Switching 374 from day 5 to day 10
# Switching 374 from day 10 to day 23
# Switching 374 from day 23 to day 75
# Switching 375 from day 25 to day 1
# Switching 375 from day 1 to day 6
# Switching 376 from day 24 to day 2
# Switching 376 from day 2 to day 26
# Switching 376 from day 26 to day 41
# Switching 376 from day 41 to day 80
# Switching 377 from day 23 to day 1
# Switching 377 from day 1 to day 11
# Switching 377 from day 11 to day 82
# Switching 378 from day 22 to day 2
# Switching 378 from day 2 to day 7
# Switching 378 from day 7 to day 8
# Switching 378 from day 8 to day 11
# Switching 378 from day 11 to day 18
# Switching 378 from day 18 to day 25
# Switching 379 from day 21 to day 1
# Switching 379 from day 1 to day 4
# Switching 380 from day 20 to day 1
# Switching 380 from day 1 to day 7
# Switching 380 from day 7 to day 69
# Switching 380 from day 69 to day 73
# Switching 381 from day 19 to day 1
# Switching 381 from day 1 to day 12
# Switching 381 from day 12 to day 15
# Switching 381 from day 15 to day 27
# Switching 382 from day 18 to day 2
# Switching 382 from day 2 to day 11
# Switching 382 from day 11 to day 17
# Switching 382 from day 17 to day 43
# Switching 382 from day 43 to day 48
# Switching 383 from day 17 to day 1
# Switching 383 from day 1 to day 12
# Switching 384 from day 16 to day 1
# Switching 384 from day 1 to day 3
# Switching 385 from day 15 to day 2
# Switching 385 from day 2 to day 29
# Switching 386 from day 14 to day 1
# Switching 386 from day 1 to day 13
# Switching 386 from day 13 to day 15
# Switching 386 from day 15 to day 66
# Switching 387 from day 13 to day 1
# Switching 387 from day 1 to day 4
# Switching 387 from day 4 to day 39
# Switching 388 from day 12 to day 2
# Switching 388 from day 2 to day 18
# Switching 388 from day 18 to day 32
# Switching 389 from day 11 to day 1
# Switching 389 from day 1 to day 36
# Switching 389 from day 36 to day 54
# Switching 390 from day 10 to day 1
# Switching 390 from day 1 to day 5
# Switching 390 from day 5 to day 40
# Switching 391 from day 9 to day 1
# Switching 391 from day 1 to day 31
# Switching 391 from day 31 to day 32
# Switching 391 from day 32 to day 40
# Switching 391 from day 40 to day 53
# Switching 391 from day 53 to day 75
# Switching 392 from day 8 to day 2
# Switching 392 from day 2 to day 16
# Switching 392 from day 16 to day 47
# Switching 392 from day 47 to day 60
# Switching 393 from day 7 to day 1
# Switching 393 from day 1 to day 5
# Switching 393 from day 5 to day 36
# Switching 394 from day 6 to day 2
# Switching 394 from day 2 to day 4
# Switching 394 from day 4 to day 11
# Switching 395 from day 5 to day 1
# Switching 395 from day 1 to day 8
# Switching 396 from day 4 to day 2
# Switching 397 from day 3 to day 2
# Switching 397 from day 2 to day 12
# Switching 397 from day 12 to day 26
# Switching 397 from day 26 to day 46
# Switching 397 from day 46 to day 52
# Switching 398 from day 2 to day 1
# Switching 398 from day 1 to day 17
# Switching 398 from day 17 to day 37
# Switching 399 from day 1 to day 2
# Switching 399 from day 2 to day 5
# Switching 400 from day 100 to day 2
# Switching 400 from day 2 to day 3
# Switching 401 from day 99 to day 1
# Switching 401 from day 1 to day 4
# Switching 401 from day 4 to day 52
# Switching 402 from day 98 to day 2
# Switching 402 from day 2 to day 4
# Switching 402 from day 4 to day 25
# Switching 403 from day 97 to day 2
# Switching 403 from day 2 to day 8
# Switching 403 from day 8 to day 17
# Switching 404 from day 96 to day 1
# Switching 404 from day 1 to day 7
# Switching 404 from day 7 to day 48
# Switching 405 from day 95 to day 1
# Switching 405 from day 1 to day 24
# Switching 405 from day 24 to day 54
# Switching 405 from day 54 to day 87
# Switching 406 from day 94 to day 1
# Switching 406 from day 1 to day 3
# Switching 407 from day 93 to day 2
# Switching 407 from day 2 to day 6
# Switching 407 from day 6 to day 10
# Switching 407 from day 10 to day 18
# Switching 407 from day 18 to day 68
# Switching 408 from day 92 to day 2
# Switching 408 from day 2 to day 5
# Switching 408 from day 5 to day 21
# Switching 409 from day 91 to day 1
# Switching 409 from day 1 to day 3
# Switching 409 from day 3 to day 5
# Switching 409 from day 5 to day 81
# Switching 410 from day 90 to day 2
# Switching 410 from day 2 to day 81
# Switching 411 from day 89 to day 1
# ...
# Switching 1555 from day 6 to day 37
# Switching 1560 from day 25 to day 88
# Switching 1649 from day 6 to day 46
# Switching 1663 from day 36 to day 19
# Switching 1667 from day 96 to day 53
# Switching 1673 from day 37 to day 39
# Switching 1700 from day 8 to day 73
# Switching 1737 from day 17 to day 7
# Switching 1791 from day 27 to day 30
# Switching 1816 from day 12 to day 68
# Switching 1857 from day 74 to day 8
# Switching 1875 from day 42 to day 74
# Switching 1919 from day 47 to day 25
# Switching 1924 from day 17 to day 3
# Switching 1963 from day 2 to day 73
# Switching 1989 from day 83 to day 17
# Switching 2001 from day 7 to day 17
# Switching 2016 from day 26 to day 25
# Switching 2026 from day 32 to day 91
# Switching 2035 from day 59 to day 23
# Switching 2082 from day 17 to day 49
# Switching 2180 from day 28 to day 24
# Switching 2306 from day 33 to day 6
# Switching 2326 from day 23 to day 87
# Switching 2348 from day 25 to day 75
# Switching 2382 from day 59 to day 23
# Switching 2405 from day 42 to day 25
# Switching 2476 from day 75 to day 9
# Switching 2490 from day 18 to day 47
# Switching 2528 from day 24 to day 53
# Switching 2595 from day 22 to day 38
# Switching 2621 from day 8 to day 87
# Switching 2699 from day 80 to day 60
# Switching 2821 from day 81 to day 18
# Switching 2850 from day 53 to day 80
# Switching 2899 from day 73 to day 10
# Switching 2926 from day 52 to day 35
# Switching 2956 from day 14 to day 26
# Switching 2972 from day 40 to day 9
# Switching 3144 from day 41 to day 96
# Switching 3210 from day 7 to day 25
# Switching 3234 from day 43 to day 73
# Switching 3264 from day 5 to day 59
# Switching 3352 from day 21 to day 94
# Switching 3373 from day 9 to day 33
# Switching 3465 from day 81 to day 24
# Switching 3528 from day 48 to day 28
# Switching 3536 from day 17 to day 21
# Switching 3568 from day 59 to day 27
# Switching 3569 from day 33 to day 2
# Switching 3578 from day 82 to day 80
# Switching 3588 from day 30 to day 87
# Switching 3605 from day 39 to day 55
# Switching 3615 from day 13 to day 18
# Switching 3670 from day 55 to day 25
# Switching 3784 from day 88 to day 28
# Switching 3846 from day 80 to day 17
# Switching 3877 from day 40 to day 48
# Switching 3997 from day 20 to day 16
# Switching 4009 from day 19 to day 5
# Switching 4009 from day 5 to day 33
# Switching 4011 from day 21 to day 95
# Switching 4037 from day 28 to day 59
# Switching 4055 from day 2 to day 18
# Switching 4083 from day 74 to day 26
# Switching 4090 from day 7 to day 5
# Switching 4148 from day 91 to day 41
# Switching 4193 from day 7 to day 81
# Switching 4212 from day 96 to day 23
# Switching 4222 from day 48 to day 43
# Switching 4228 from day 44 to day 87
# Switching 4280 from day 41 to day 15
# Switching 4322 from day 4 to day 26
# Switching 4381 from day 47 to day 28
# Switching 4393 from day 95 to day 14
# Switching 4393 from day 14 to day 31
# Switching 4396 from day 7 to day 13
# Switching 4431 from day 67 to day 30
# Switching 4503 from day 33 to day 4
# Switching 4506 from day 68 to day 48
# Switching 4507 from day 31 to day 30
# Switching 4533 from day 29 to day 82
# Switching 4568 from day 56 to day 66
# Switching 4648 from day 10 to day 7
# Switching 4674 from day 69 to day 10
# Switching 4707 from day 19 to day 47
# Switching 4737 from day 23 to day 6
# Switching 4765 from day 10 to day 66
# Switching 4795 from day 46 to day 62
# Switching 4848 from day 42 to day 61
# Switching 4857 from day 94 to day 8
# Switching 4912 from day 18 to day 9
# Switching 4943 from day 30 to day 17
# Switching 4980 from day 28 to day 52
# Round 25: Changed family days.  New cost: 106228.12965026154
# Switching 61 from day 18 to day 15
# Switching 69 from day 22 to day 5
# Switching 142 from day 26 to day 37
# Switching 188 from day 20 to day 10
# Switching 249 from day 75 to day 14
# Switching 259 from day 12 to day 60
# Switching 261 from day 83 to day 67
# Switching 354 from day 87 to day 27
# Switching 405 from day 87 to day 54
# Switching 427 from day 24 to day 42
# Switching 453 from day 62 to day 51
# Switching 577 from day 88 to day 31
# Switching 694 from day 59 to day 56
# Switching 694 from day 56 to day 96
# Switching 719 from day 73 to day 32
# Switching 774 from day 6 to day 26
# Switching 977 from day 54 to day 7
# Switching 1036 from day 25 to day 7
# Switching 1129 from day 32 to day 80
# Switching 1141 from day 9 to day 87
# Switching 1250 from day 13 to day 38
# Switching 1278 from day 82 to day 27
# Switching 1311 from day 45 to day 6
# Switching 1342 from day 48 to day 88
# Switching 1387 from day 5 to day 48
# Switching 1405 from day 53 to day 56
# Switching 1550 from day 22 to day 12
# Switching 1799 from day 54 to day 7
# Switching 1844 from day 38 to day 75
# Switching 1857 from day 8 to day 33
# Switching 1960 from day 47 to day 2
# Switching 2019 from day 94 to day 22
# Switching 2151 from day 55 to day 32
# Switching 2234 from day 26 to day 52
# Switching 2269 from day 32 to day 16
# Switching 2379 from day 60 to day 76
# Switching 2382 from day 23 to day 59
# Switching 2396 from day 31 to day 20
# Switching 2654 from day 20 to day 45
# Switching 2713 from day 48 to day 94
# Switching 2738 from day 96 to day 56
# Switching 2850 from day 80 to day 53
# Switching 2892 from day 6 to day 32
# Switching 2918 from day 21 to day 39
# Switching 2931 from day 17 to day 8
# Switching 2933 from day 45 to day 43
# Switching 3050 from day 15 to day 60
# Switching 3146 from day 52 to day 13
# Switching 3159 from day 81 to day 62
# Switching 3215 from day 83 to day 25
# Switching 3223 from day 60 to day 12
# Switching 3480 from day 32 to day 83
# Switching 3510 from day 24 to day 15
# Switching 3511 from day 49 to day 96
# Switching 3670 from day 25 to day 55
# Switching 3829 from day 82 to day 68
# Switching 3841 from day 15 to day 82
# Switching 3847 from day 89 to day 6
# Switching 3877 from day 48 to day 40
# Switching 3907 from day 43 to day 19
# Switching 3924 from day 45 to day 22
# Switching 4037 from day 59 to day 28
# Switching 4086 from day 76 to day 26
# Switching 4088 from day 58 to day 24
# Switching 4156 from day 36 to day 69
# Switching 4285 from day 4 to day 20
# Switching 4312 from day 44 to day 26
# Switching 4338 from day 22 to day 25
# Switching 4391 from day 19 to day 9
# Switching 4431 from day 30 to day 67
# Switching 4558 from day 18 to day 4
# Switching 4567 from day 12 to day 34
# Switching 4584 from day 90 to day 38
# Switching 4637 from day 24 to day 30
# Switching 4648 from day 7 to day 10
# Switching 4674 from day 10 to day 69
# Switching 4787 from day 28 to day 18
# Switching 4808 from day 40 to day 62
# Switching 4961 from day 16 to day 54
# Round 26: Changed family days.  New cost: 105218.32959208437
# Switching 59 from day 39 to day 15
# Switching 283 from day 9 to day 73
# Switching 298 from day 50 to day 19
# Switching 316 from day 53 to day 44
# Switching 357 from day 25 to day 55
# Switching 397 from day 76 to day 52
# Switching 413 from day 62 to day 80
# Switching 427 from day 42 to day 24
# Switching 462 from day 80 to day 58
# Switching 487 from day 26 to day 21
# Switching 648 from day 38 to day 48
# Switching 836 from day 13 to day 31
# Switching 909 from day 52 to day 36
# Switching 966 from day 6 to day 59
# Switching 1009 from day 75 to day 42
# Switching 1293 from day 12 to day 62
# Switching 1568 from day 36 to day 40
# Switching 1701 from day 73 to day 52
# Switching 1870 from day 37 to day 95
# Switching 1975 from day 43 to day 73
# Switching 2088 from day 94 to day 25
# Switching 2306 from day 6 to day 33
# Switching 2560 from day 48 to day 12
# Switching 2574 from day 12 to day 8
# Switching 2673 from day 83 to day 15
# Switching 2933 from day 43 to day 45
# Switching 3000 from day 31 to day 14
# Switching 3016 from day 45 to day 16
# Switching 3099 from day 96 to day 83
# Switching 3895 from day 25 to day 7
# Switching 4020 from day 15 to day 8
# Switching 4156 from day 69 to day 36
# Switching 4156 from day 36 to day 94
# Switching 4542 from day 66 to day 6
# Switching 4857 from day 8 to day 94
# Switching 4980 from day 52 to day 28
# Round 27: Changed family days.  New cost: 104926.91722213804
# Switching 39 from day 10 to day 9
# Switching 112 from day 60 to day 13
# Switching 142 from day 37 to day 26
# Switching 261 from day 67 to day 83
# Switching 316 from day 44 to day 53
# Switching 647 from day 16 to day 69
# Switching 774 from day 26 to day 6
# Switching 977 from day 7 to day 54
# Switching 1554 from day 83 to day 10
# Switching 1574 from day 6 to day 60
# Switching 1613 from day 9 to day 17
# Switching 1627 from day 13 to day 46
# Switching 1870 from day 95 to day 37
# Switching 2486 from day 26 to day 16
# Switching 3000 from day 14 to day 31
# Switching 3014 from day 6 to day 68
# Switching 3223 from day 12 to day 25
# Switching 3841 from day 82 to day 15
# Switching 3927 from day 21 to day 12
# Switching 4048 from day 83 to day 42
# Switching 4280 from day 15 to day 41
# Switching 4338 from day 25 to day 22
# Switching 4440 from day 41 to day 40
# Switching 4566 from day 42 to day 26
# Switching 4628 from day 40 to day 21
# Switching 4673 from day 17 to day 9
# Switching 4698 from day 54 to day 13
# Switching 4701 from day 31 to day 15
# Switching 4901 from day 46 to day 78
# Switching 4926 from day 78 to day 67
# Switching 4939 from day 51 to day 25
# Round 28: Changed family days.  New cost: 104583.31170765685
# Switching 123 from day 22 to day 95
# Switching 356 from day 33 to day 51
# Switching 487 from day 21 to day 26
# Switching 636 from day 80 to day 21
# Switching 703 from day 56 to day 66
# Switching 785 from day 73 to day 56
# Switching 835 from day 8 to day 17
# Switching 926 from day 18 to day 33
# Switching 1482 from day 33 to day 23
# Switching 1554 from day 10 to day 83
# Switching 1574 from day 60 to day 6
# Switching 1674 from day 37 to day 54
# Switching 1791 from day 30 to day 27
# Switching 1911 from day 67 to day 8
# Switching 1973 from day 95 to day 33
# Switching 2011 from day 25 to day 28
# Switching 2306 from day 33 to day 6
# Switching 2549 from day 17 to day 80
# Switching 2595 from day 38 to day 22
# Switching 2800 from day 29 to day 67
# Switching 2828 from day 2 to day 24
# Switching 2864 from day 87 to day 60
# Switching 2907 from day 81 to day 5
# Switching 2931 from day 8 to day 17
# Switching 2972 from day 9 to day 40
# Switching 3046 from day 5 to day 23
# Switching 3119 from day 37 to day 18
# Switching 3159 from day 62 to day 81
# Switching 3540 from day 23 to day 90
# Switching 4300 from day 9 to day 87
# Switching 4398 from day 83 to day 29
# Switching 4478 from day 21 to day 73
# Switching 4542 from day 6 to day 66
# Switching 4835 from day 82 to day 51
# Switching 4980 from day 28 to day 52
# Round 29: Changed family days.  New cost: 104342.97625759152
# Switching 69 from day 5 to day 22
# Switching 283 from day 73 to day 9
# Switching 290 from day 56 to day 25
# Switching 298 from day 19 to day 50
# Switching 1141 from day 87 to day 9
# Switching 1568 from day 40 to day 36
# Switching 2008 from day 12 to day 89
# Switching 2082 from day 49 to day 17
# Switching 2095 from day 13 to day 82
# Switching 2168 from day 36 to day 95
# Switching 2527 from day 89 to day 42
# Switching 2633 from day 90 to day 87
# Switching 2931 from day 17 to day 8
# Switching 3215 from day 25 to day 83
# Switching 4404 from day 8 to day 10
# Switching 4430 from day 9 to day 96
# Switching 4571 from day 96 to day 8
# Switching 4809 from day 51 to day 73
# Switching 4980 from day 52 to day 28
# Round 30: Changed family days.  New cost: 104201.05217738655
# Switching 298 from day 50 to day 19
# Switching 1387 from day 48 to day 5
# Switching 2574 from day 8 to day 12
# Switching 2972 from day 40 to day 9
# Switching 4523 from day 47 to day 88
# Round 31: Changed family days.  New cost: 104169.84715780156
# Switching 61 from day 15 to day 18
# Switching 354 from day 27 to day 87
# Switching 488 from day 7 to day 40
# Switching 685 from day 46 to day 34
# Switching 951 from day 88 to day 8
# Switching 2591 from day 34 to day 9
# Switching 2781 from day 88 to day 34
# Switching 2821 from day 18 to day 81
# Switching 3159 from day 81 to day 62
# Switching 3588 from day 87 to day 30
# Switching 4047 from day 89 to day 7
# Switching 4086 from day 26 to day 76
# Switching 4193 from day 81 to day 7
# Switching 4381 from day 28 to day 47
# Switching 4912 from day 9 to day 18
# Round 32: Changed family days.  New cost: 104107.16532668985
# Switching 507 from day 47 to day 13
# Switching 563 from day 76 to day 47
# Switching 1448 from day 36 to day 89
# Switching 2098 from day 5 to day 36
# Switching 2539 from day 59 to day 14
# Switching 2633 from day 87 to day 90
# Switching 3119 from day 18 to day 37
# Switching 3534 from day 13 to day 38
# Switching 3588 from day 30 to day 87
# Switching 4041 from day 7 to day 47
# Switching 4748 from day 37 to day 59
# Round 33: Changed family days.  New cost: 104050.79128525921
# Switching 296 from day 50 to day 39
# Switching 298 from day 19 to day 50
# Switching 563 from day 47 to day 76
# Switching 951 from day 8 to day 88
# Switching 1009 from day 42 to day 75
# Switching 1673 from day 39 to day 37
# Switching 1674 from day 54 to day 37
# Switching 3303 from day 55 to day 52
# Switching 3348 from day 17 to day 51
# Round 34: Changed family days.  New cost: 104007.78832365063
# Switching 1673 from day 37 to day 39
# Switching 1696 from day 22 to day 17
# Switching 4943 from day 17 to day 30
# Round 35: Changed family days.  New cost: 103985.79195288113
# Switching 296 from day 39 to day 50
# Switching 2049 from day 30 to day 94
# Switching 2269 from day 16 to day 32
# Switching 3588 from day 87 to day 30
# Switching 4156 from day 94 to day 36
# Switching 4233 from day 32 to day 30
# Switching 4595 from day 3 to day 37
# Round 36: Changed family days.  New cost: 103962.0686632384
# Switching 64 from day 12 to day 3
# Switching 1129 from day 80 to day 32
# Switching 2135 from day 43 to day 31
# Switching 2633 from day 90 to day 87
# Switching 2699 from day 60 to day 80
# Round 37: Changed family days.  New cost: 103880.23506920578
# Switching 941 from day 23 to day 90
# Switching 2527 from day 42 to day 89
# Switching 2828 from day 24 to day 2
# Switching 4566 from day 26 to day 42
# Round 38: Changed family days.  New cost: 103857.48823533417
# Switching 414 from day 8 to day 26
# Switching 720 from day 53 to day 8
# Switching 1131 from day 73 to day 24
# Switching 1264 from day 24 to day 98
# Switching 1405 from day 56 to day 53
# Switching 1562 from day 98 to day 7
# Switching 2057 from day 7 to day 39
# Switching 3278 from day 31 to day 23
# Switching 3588 from day 30 to day 87
# Round 39: Changed family days.  New cost: 103728.218305732
# Round 40: Swapped families.  New cost: 100597.66089364939
# Switching 123 from day 95 to day 22
# Switching 278 from day 78 to day 46
# Switching 278 from day 46 to day 54
# Switching 671 from day 48 to day 17
# Switching 671 from day 17 to day 44
# Switching 977 from day 54 to day 7
# Switching 1036 from day 7 to day 25
# Switching 1720 from day 22 to day 24
# Switching 2490 from day 18 to day 47
# Switching 2560 from day 12 to day 48
# Switching 2690 from day 11 to day 12
# Switching 2699 from day 80 to day 60
# Switching 2964 from day 3 to day 11
# Switching 3181 from day 14 to day 46
# Switching 3646 from day 24 to day 19
# Switching 3800 from day 19 to day 80
# Switching 3916 from day 5 to day 46
# Switching 4004 from day 23 to day 5
# Switching 4595 from day 37 to day 3
# Round 41: Changed family days.  New cost: 100329.99436421209
# Switching 99 from day 39 to day 23
# Switching 156 from day 44 to day 95
# Switching 788 from day 19 to day 15
# Switching 1228 from day 29 to day 19
# Switching 2168 from day 95 to day 36
# Switching 2352 from day 30 to day 81
# Switching 2353 from day 32 to day 35
# Switching 2464 from day 19 to day 29
# Switching 3181 from day 46 to day 14
# Switching 3534 from day 38 to day 13
# Switching 3588 from day 87 to day 30
# Switching 3800 from day 80 to day 19
# Switching 4983 from day 19 to day 16
# Round 42: Changed family days.  New cost: 100265.78404424414
# Switching 298 from day 50 to day 19
# Switching 1293 from day 62 to day 12
# Switching 1715 from day 2 to day 17
# Switching 2933 from day 45 to day 43
# Switching 3415 from day 51 to day 80
# Switching 3773 from day 17 to day 51
# Round 43: Changed family days.  New cost: 100240.43124552508
# Round 44: Swapped families.  New cost: 100197.55643294282
# Switching 3364 from day 4 to day 62
# Round 45: Changed family days.  New cost: 100196.73340264753
# Round 46: Swapped families.  New cost: 100151.35716339452

# %%
print('making submission')
submission['assigned_day'] = new
# Out:
# making submission

# %%
submission.to_csv('submission.csv')
